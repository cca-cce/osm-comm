# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/cca-cce/osm-comm/blob/main/jnb/simm59/simm59_assignment.ipynb)

# %% [markdown]
# # General Instructions
#
# This final assignment assesses your ability to design and conduct document-based research using both qualitative and quantitative approaches, in line with the course learning outcomes on selecting, applying, and critically evaluating document analysis methods.
#
# You will complete **two complementary tasks within the same Jupyter Notebook (.ipynb) file**, introduced during the first computer lab. The notebook should be clearly structured using text (Markdown) and, where appropriate, code cells, and organized into the sections: *Introduction, Methods, Results, Discussion*.
#
# - Use **Markdown/text cells** for explanations, interpretation, and reporting in both tasks.
# - Use **code cells only in Task 2**.
# - Ensure transparency and reproducibility in your analytical workflow.
# - Clearly separate Task 1 and Task 2 within the same notebook using headings.
# - The assignment is worth a total of 100 points.

# %% [markdown]
# # Task 1: Design a Qualitative Document Study
#
# In this task, you will conduct a **document-based research study** within the social sciences. The task is to produce a structured research proposal focusing on **empirical design and methodological reasoning**, rather than theoretical contribution.
#
# Your proposal should demonstrate your ability to:
# *   Formulate a clear and researchable problem grounded in documents as data
# *   Develop coherent research questions
# *   Select and justify appropriate documents and analytical strategies
# *   Reflect critically on methodological and ethical issues in document research
#
# This is not a full research proposal. You must **not** include a theoretical framework or literature review section. However, your study should still reflect awareness of relevant concepts and methodological debates where appropriate.
#
# **Scope and points**: 2200 words +/- 10% and 67 points.
#
# **References**: Refer to the course literature and other literature where relevant. Be meticulous, follow an established referencing style (e.g. APA) and refer to page numbers when appropriate. If you refer to literature that's not in the course literature, you MUST include a bibliography (the bibliography does *not* count towards the total word count).
#
# ## Suggested structure:
# - **Introduction and aim**: Introduce the empirical topic and context of the study, clearly define the **aim of the study**
# - **Research Questions**: Formulate 2-4 research questions. These should:
#     *   be analytically clear and answerable through document analysis
#     *   Alignwith the stated aim
#     *   Avoid being overly descriptive or excessively broad
# - **Methodology**: Here, you must demonstrate detailed and justified methodological decision-making. It should include some discussion of the following:
#     *   Specify the type of document study and justify your chosen approach in relation to your research questions.
#     *   Data selection (e.g. sampling, scope, type of document)
#     *   Data collection procedure (how the documents will be accessed, discuss any practical constraints, and reflect on potential biases in their availability or selection).
#     *   Analytical strategy, *briefly* (e.g. thematic coding, discourse analysis etc.)
#     *   Ethical considerations
#
#
# The assessment is based on the extent to which the student **demonstrates knowledge** of document-based research strategies and genres, the ability to **apply and justify appropriate methods** for selecting and analysing documents in relation to a coherent research design, and the capacity to **use relevant concepts and terminology** with precision. It evaluates the student's proficiency in developing a **feasible and analytically clear** document study, as well as their ability to **critically assess the possibilities and limitations** of document research, including issues of bias, interpretation, and epistemological positioning, in line with the course learning outcomes.

# %% [markdown]
# # Task 2: Quantitative / Computational Document Analysis
#
# In this task, you will conduct a **computational analysis of textual data** using Python.
#
# - Work in the same notebook using a combination of **Markdown and code cells**.
# - Build your own **small text corpus** (e.g., 5–15 documents) collected from **publicly available online sources**.
# - Clearly document your data collection and justify your corpus in relation to your research question.
#
# You may choose among several analytical approaches introduced in the course, including but not limited to text preprocessing (e.g., cleaning and tokenization), linguistic annotation (e.g., named entity recognition and part-of-speech tagging), exploratory techniques (e.g., keyword-in-context or frequency analysis), and semantic methods (e.g., word embeddings and vector similarity). You are not required to use all techniques; instead, select and justify a subset that is appropriate for your research question.
#
# **Scope and points**: 1100 words +/- 10% and 33 points.
#
# ## Suggested structure:
# - **Introduction**: Research question and analytical focus
# - **Data & Methods**: Corpus construction and analytical approach
# - **Results**: Outputs from your selected methods
# - **Discussion**: Interpretation, limitations, and methodological reflection

# %%
print("This is an NLP code cell!")
# Out:
# This is an NLP code cell!

# %% [markdown]
# # Assessment Criteria
#
# Your work will be evaluated in relation to the course learning outcomes, including:
#
# - Ability to **select and justify document-based methods**
# - Use of **appropriate concepts and terminology**
# - Demonstration of **multiple strategies of document analysis**
# - Critical reflection on **strengths and limitations of document research**
#
# Higher grades require increasing levels of analytical depth, methodological rigor, and critical reflection.
#
# | Grade | Points |
# |-------|--------|
# | A     | 90–100 |
# | B     | 80–89  |
# | C     | 70–79  |
# | D     | 60–69  |
# | E     | 50–59  |
# | F     | 0–49   |
