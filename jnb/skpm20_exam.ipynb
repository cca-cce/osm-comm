z0L4hbE48oN3SJhFwWTao4DsYlALZjbCoHtj9Fs_MDSEmyRzYYGYGYeYQ_7pUsDx5qlT873AC1EvAVb6yb1J7goa1tuvqcIePA3JMXWmER6uhKlYG-J9S5diV4hKpJjCloORFKfqAJiaqd9aVz3M6GZdYLpipYWoqTlzYiEZvKdzSXsfzYNulMM0CDsKTPd4C1ESj2dxHCfRdEJI6BMP7yBLZuNklsziMPCjKAnDg4f_dJr-eBpFs2niTyKYdRKS4PAXVugvxA)
#
# - Perform descriptive statistics and data transformations
# - Perform bivariate analyses and hypothesis testing
# - Perform multivariate analysis, multiple regression

# %% [markdown]
# ## loading dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats

# Load the dataset
path = "penguins.tsv"
path = "https://github.com/cca-cce/osm-comm/raw/refs/heads/main/csv/penguins.tsv"
df = pd.read_csv(path, sep="\t")

print(df.shape)
print(df.columns[:15])
# Out:
# (344, 7)
# Index(['species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex'],
#       dtype='object')

# %% [markdown]
# ## selecting data

# %%
# theoretical model, select variables, save data subset as tsv

# %% [markdown]
# # 1. Descriptive statistics

# %%
# code cell 1, keep this comment, edit content but do not add more code cells

# %%
# code cell 2, keep this comment, edit content but do not add more code cells

# %%
# code cell 3, keep this comment, edit content but do not add more code cells

# %%
# code cell 4, keep this comment, edit content but do not add more code cells

# %% [markdown]
# # 2. Data transformations

# %%
# code cell 1, keep this comment, edit content but do not add more code cells

# %%
# code cell 2, keep this comment, edit content but do not add more code cells

# %%
# code cell 3, keep this comment, edit content but do not add more code cells

# %%
# code cell 4, keep this comment, edit content but do not add more code cells

# %% [markdown]
# # 3. Bivariate analysis

# %%
# code cell 1, keep this comment, edit content but do not add more code cells

# %%
# code cell 2, keep this comment, edit content but do not add more code cells

# %%
# code cell 3, keep this comment, edit content but do not add more code cells

# %%
# code cell 4, keep this comment, edit content but do not add more code cells

# %% [markdown]
# # 4. Hypothesis testing

# %%
# code cell 1, keep this comment, edit content but do not add more code cells

# %%
# code cell 2, keep this comment, edit content but do not add more code cells

# %%
# code cell 3, keep this comment, edit content but do not add more code cells

# %%
# code cell 4, keep this comment, edit content but do not add more code cells

# %% [markdown]
# # 5. Multivariate analysis

# %%
# code cell 1, keep this comment, edit content but do not add more code cells

# %%
# code cell 2, keep this comment, edit content but do not add more code cells

# %%
# code cell 3, keep this comment, edit content but do not add more code cells

# %%
# code cell 4, keep this comment, edit content but do not add more code cells
